# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Desktop\lead_pre.csv")
df
# Out:
#        Unnamed: 0  status       lost_reason  budget duration  \
# 0               0       0    Not responding     190   others
# 1               1       0        Low budget     190   others
# 2               2       0    Not responding     150       42
# 3               3       0        Low budget       0        0
# 4               4       0         Junk lead     190   others
# ...           ...     ...               ...     ...      ...
# 46312       46312       0  Low availability      90       51
# 46313       46313       0     Semester stay      90       10
# 46314       46314       0  Low availability     190       42
# 46315       46315       0  Low availability     190   others
# 46316       46316       0  Low availability     210       42
#
#                                                   source  \
# 0                                                    NaN
# 1                                                    NaN
# 2      7aae3e886e89fc1187a5c47d6cea1c22998ee610ade1f2...
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace = True)

# %%
print(df.describe())
# Out:
#              status        budget
# count  46317.000000  46317.000000
# mean       0.066347    135.815143
# std        0.248891     64.928387
# min        0.000000      0.000000
# 25%        0.000000     90.000000
# 50%        0.000000    150.000000
# 75%        0.000000    190.000000
# max        1.000000    210.000000

# %%
# Countplot of the 'status' column
sns.countplot(x='status', data=df)
plt.title('Status')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='lost_reason', data=df, order=df['lost_reason'].value_counts().index)
plt.title('Lost Reason')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['budget'], kde=True, bins=20)
plt.title('Budget')
plt.xticks(rotation=45)
plt.gca().invert_xaxis()  # Invert the x-axis to sort bins in descending order
plt.show()

# %%
# Scatter plot of 'budget' vs. 'duration'
plt.figure(figsize=(10, 5))
sns.scatterplot(x='budget', y='duration', data=df)
plt.title('Budget vs. Duration')
plt.show()

# %%
# Distribution Analysis
df.hist(figsize=(10, 8), bins=20)
plt.tight_layout()
plt.show()

# %%
# Outlier Detection
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['budget', 'duration']])
plt.title('Outlier Detection')
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['status'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Lead Status')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['lost_reason'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Lost Reason')
plt.ylabel('')
plt.show()
